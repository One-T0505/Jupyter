# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# %%
cancer = load_breast_cancer()

# %%
x_train, x_test, y_train, y_test = train_test_split(cancer.data, cancer.target, random_state=26, test_size=0.2)

# %%
train_acc = []
test_acc  = []
for i in range(1,31):
    model = KNeighborsClassifier(n_neighbors=i)
    model.fit(x_train, y_train)
    train_acc.append(model.score(x_train, y_train))
    test_acc.append(model.score(x_test, y_test))
print(f"训练准确率为：{train_acc}\n测试准确率为：{test_acc}")
# Out:
# 训练准确率为：[1.0, 0.967032967032967, 0.9516483516483516, 0.945054945054945, 0.9406593406593406, 0.9362637362637363, 0.9384615384615385, 0.9384615384615385, 0.9384615384615385, 0.9406593406593406, 0.9362637362637363, 0.9406593406593406, 0.9406593406593406, 0.9340659340659341, 0.9296703296703297, 0.9296703296703297, 0.9274725274725275, 0.9318681318681319, 0.9296703296703297, 0.9296703296703297, 0.9274725274725275, 0.9274725274725275, 0.9296703296703297, 0.9318681318681319, 0.9274725274725275, 0.9274725274725275, 0.9252747252747253, 0.9252747252747253, 0.9164835164835164, 0.9186813186813186]
# ...

# %%
fig = plt.figure(figsize=(8, 6), dpi=100)
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False
plt.plot(range(1, 31), train_acc, label="训练精度")
plt.plot(range(1, 31), test_acc, label="测试精度")
plt.legend()
