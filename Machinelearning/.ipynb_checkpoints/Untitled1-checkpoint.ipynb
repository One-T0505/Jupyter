# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# %%
data = pd.read_csv('D:/datasets/breast_cancer/breast-cancer-wisconsin.data')
data.head(5)
# Out:
#    1000025  5   1  1.1  1.2  2 1.3  3  1.4  1.5  2.1
# 0  1002945  5   4    4    5  7  10  3    2    1    2
# 1  1015425  3   1    1    1  2   2  3    1    1    2
# 2  1016277  6   8    8    1  3   4  3    7    1    2
# 3  1017023  4   1    1    3  2   1  3    1    1    2
# 4  1017122  8  10   10    8  7  10  9    7    1    4

# %%
column_names = ['Sample code number', 'Clump Thickness', 'Uniformity of Cell Size', 'Uniformity of Cell Shape', 'Marginal Adhesion',             
                'Single Epithelial Cell Size', 'Bare Nuclei', 'Bland Chromatin', 'Normal Nucleoli', 'Mitoses', 'Class']               
data.columns = column_names
data
# Out:
#      Sample code number  Clump Thickness  Uniformity of Cell Size  \
# 0               1002945                5                        4
# 1               1015425                3                        1
# 2               1016277                6                        8
# 3               1017023                4                        1
# 4               1017122                8                       10
# ..                  ...              ...                      ...
# 693              776715                3                        1
# 694              841769                2                        1
# 695              888820                5                       10
# 696              897471                4                        8
# 697              897471                4                        8
#
#      Uniformity of Cell Shape  Marginal Adhesion  Single Epithelial Cell Size  \
# 0                           4                  5                            7
# ...

# %% [markdown]
# - 缺失值处理

# %%
data.replace(to_replace="?", value=np.nan, inplace=True)
data.dropna(inplace=True)
data.describe()
# Out:
#        Sample code number  Clump Thickness  Uniformity of Cell Size  \
# count        6.820000e+02       682.000000               682.000000
# mean         1.076833e+06         4.441349                 3.153959
# std          6.210926e+05         2.822751                 3.066285
# min          6.337500e+04         1.000000                 1.000000
# 25%          8.774540e+05         2.000000                 1.000000
# 50%          1.171820e+06         4.000000                 1.000000
# 75%          1.238741e+06         6.000000                 5.000000
# max          1.345435e+07        10.000000                10.000000
#
#        Uniformity of Cell Shape  Marginal Adhesion  \
# count                682.000000         682.000000
# mean                   3.218475           2.832845
# std                    2.989568           2.865805
# min                    1.000000           1.000000
# 25%                    1.000000           1.000000
# ...

# %% [markdown]
# - 确定特征值和目标值
#     - 特征值为除了 Sample code number 和 class 的属性， 目标值为 class

# %%
x = data.iloc[:, 1:-1]
y = data['Class']

# %% [markdown]
# - 数据分割

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=22)

# %% [markdown]
# - 数据标准化

# %%
transfer = StandardScaler()
x_train = transfer.fit_transform(x_train)
x_test = transfer.fit_transform(x_test)

# %% [markdown]
# - 模型训练

# %%
model = LogisticRegression()
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# + 模型评估
#     * 基本评估

# %%
score = model.score(x_test, y_test)
print("模型的准确率是：\n", score)
# Out:
# 模型的准确率是：
#  0.9562043795620438

# %% [markdown]
# - 高级评估

# %%
y_pre = model.predict(x_test)
report = classification_report(y_test, y_pre, labels=(2, 4), target_names=['良性', '恶性'])
print(report)
# Out:
#               precision    recall  f1-score   support
#
#           良性       0.95      0.98      0.97        85
#           恶性       0.96      0.92      0.94        52
#
#     accuracy                           0.96       137
#    macro avg       0.96      0.95      0.95       137
# weighted avg       0.96      0.96      0.96       137

# %%
-1*(9/7*np.log2(3)+5/14*np.log2(5)-1-np.log2(7))
# Out:
# 0.9402859586706311

# %%
-0.5*(3/7*np.log2(3/7)+4/7*np.log2(4/7))-0.5*(6/7*np.log2(6/7)+1/7*np.log2(1/7))
# Out:
# 0.7884504573082896

# %%
arr1, arr2 = np.vsplit(np.array([[1, 2, 3], [4, 5, 6]]), indices_or_sections=2)

# %%
arr1.squeeze().shape
# Out:
# (3,)
