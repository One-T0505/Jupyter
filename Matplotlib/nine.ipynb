# %% [markdown]
# ## 直方图

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  ![image.png](attachment:image.png)

# %%
value = np.random.randint(140, 200, 300)
plt.hist(value, bins=15, edgecolor='white')
# Out:
# (array([19., 23., 19., 20., 24., 13., 27., 22., 16., 16., 18., 21., 25.,
#         15., 22.]),
#  array([140.        , 143.93333333, 147.86666667, 151.8       ,
#         155.73333333, 159.66666667, 163.6       , 167.53333333,
#         171.46666667, 175.4       , 179.33333333, 183.26666667,
#         187.2       , 191.13333333, 195.06666667, 199.        ]),
#  <BarContainer object of 15 artists>)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 添加折线直方图

# %% [markdown]
#  ## 饼状图

# %% [markdown]
# ![image.png](attachment:image.png)
